# %% [markdown]
# # Notebook used for prototyping (ignore)

# %%
import pickle
import os
from PIL import Image
import matplotlib.pyplot as plt
from itertools import islice
import pandas as pd
from keras.preprocessing.image import ImageDataGenerator

# %%
len(room_names)
# Out:
# 215

# %%
# make list of all room names
room_names = os.listdir('../data/room_scenes/')
# df = pd.DataFrame(columns=room_names)
# make pd series of room_names

# %%
data2 = {key: [value] for key, value in data.items()}
df = pd.DataFrame.from_dict(data2, orient='index').reset_index()
df.columns = ['fname', 'room']
df.head()
# Out:
#                        fname  \
# 0      images/500.210.76.jpg
# 1  images/bed/802.538.09.jpg
# 2      images/802.962.48.jpg
# 3      images/502.962.97.jpg
# 4      images/203.086.97.jpg
#
#                                                 room
# 0  [images/room_scenes/ikea-a-colourful-room-for-...
# 1  [images/room_scenes/ikea-a-colourful-room-for-...
# 2  [images/room_scenes/ikea-a-colourful-room-for-...
# 3  [images/room_scenes/ikea-a-colourful-room-for-...
# 4  [images/room_scenes/ikea-a-colourful-room-for-...

# %%
df2 = df['fname']
df2.str.strip('images/')
df2
# Out:
# 0              images/500.210.76.jpg
# 1          images/bed/802.538.09.jpg
# 2              images/802.962.48.jpg
# 3              images/502.962.97.jpg
# 4              images/203.086.97.jpg
#                     ...
# 2173       images/bed/803.007.16.jpg
# 2174      images/sofa/690.106.19.jpg
# 2175     images/table/903.020.60.jpg
# 2176    images/pillow/702.584.83.jpg
# 2177    images/pillow/202.584.85.jpg
# Name: fname, Length: 2178, dtype: object

# %%
datagen = ImageDataGenerator(rescale=1./255)

train_generator=datagen.flow_from_dataframe(
    dataframe=df[:1800],
    directory="./miml_dataset/images",
    x_col="fname",
    y_col="room",
    batch_size=32,
    seed=42,
    shuffle=True,
    class_mode="categorical",
    classes=["desert", "mountains", "sea", "sunset", "trees"],
    target_size=(100,100))

# %%
import pickle
import os
from PIL import Image
import matplotlib.pyplot as plt
from itertools import islice

# %%
f = open('../data/text_data/item_to_room.p', 'rb')
data = pickle.load(f)
list(islice(data.items(), 5))
# Out:
# [('images/500.210.76.jpg',
#   ['images/room_scenes/ikea-a-colourful-room-for-kids-to-get-creative__1364308442737-s4.jpg',
#    'images/room_scenes/ikea-artist-studio-by-day-cosy-cocoon-by-night__1364319298429-s4.jpg',
#    'images/room_scenes/ikea-artist-studio-by-day-cosy-cocoon-by-night-1364319298711.jpg']),
#  ('images/bed/802.538.09.jpg',
#   ['images/room_scenes/ikea-a-colourful-room-for-kids-to-get-creative__1364308442737-s4.jpg',
#    'images/room_scenes/ikea-big-world-small-scale__1364319297984-s4.jpg',
#    'images/room_scenes/ikea-make-room-for-sleep-and-play__1364308428289-s4.jpg',
#    'images/room_scenes/ikea-room-to-draw-play-and-tidy-away__1364311995446-s4.jpg',
#    'images/room_scenes/ikea-snuggle-down-low-or-sleep-up-high__1364315930176-s4.jpg',
#    'images/room_scenes/ikea-snuggle-down-low-or-sleep-up-high-1364315930147.jpg']),
#  ('images/802.962.48.jpg',
#   ['images/room_scenes/ikea-a-colourful-room-for-kids-to-get-creative__1364308442737-s4.jpg',
#    'images/room_scenes/ikea-quiet-dolls-dinner-party-in-progress__1364315930974-s4.jpg',
#    'images/room_scenes/ikea-quiet-dolls-dinner-party-in-progress-1364315931914.jpg']),
#  ('images/502.962.97.jpg',
#   ['images/room_scenes/ikea-a-colourful-room-for-kids-to-get-creative__1364308442737-s4.jpg',
#    'images/room_scenes/ikea-how-to-sleep-and-surf-in-four-square-metres__1364315935574-s4.jpg',
#    'images/room_scenes/ikea-how-to-sleep-and-surf-in-four-square-metres-1364315936265.jpg']),
#  ('images/203.086.97.jpg',
#   ['images/room_scenes/ikea-a-colourful-room-for-kids-to-get-creative__1364308442737-s4.jpg',
#    'images/room_scenes/ikea-a-colourful-room-for-kids-to-get-creative-1364308442710.jpg'])]

# %%
# make list of all room names
room_names = os.listdir('../data/room_scenes/')
# make pd series of room_names

# if item is in room_names, then add hot encoding
# Out:
# ['ikea-a-clean-way-to-display-or-tidy-away.__1364309466684-s4.jpg',
#  'ikea-snuggle-down-in-cosy-traditional-green-__1364308476013-s4.jpg',
#  'ikea-sometimes-storage-is-better-in-pairs__1364308453074-s4.jpg',
#  'ikea-traditional-long-lasting-furniture-for-every-generation__1364309710705-s4.jpg',
#  'ikea-balcony-organisers-for-the-urban-gardener__1364308450883-s4.jpg',
#  'ikea-traditional-looks-meet-modern-versatility__1364308465624-s4.jpg',
#  'ikea-living-room-by-day-sleeping-space-by-night.__1364309472217-s4.jpg',
#  'ikea-a-sunny-space-for-celebrating-or-just-having-breakfast__1364308409238-s4.jpg',
#  'ikea-make-your-own-ultimate-gaming-space__1364308493311-s4.jpg',
#  'ikea-kid-friendly-storage-in-traditional-style__1364308477569-s4.jpg',
#  'ikea-crisp-modern-design-perfect-for-breakfast-time__1364308406824-s4.jpg',
#  'ikea-fold-out-for-drying-fold-up-for-tea__1364309312978-s4.jpg',
#  'ikea-easy-going-brunches-gourmet-lunches__1364309710394-s4.jpg',
#  'ikea-quick-set-up-slow-breakfast__1364309643667-s4.jpg',
#  'ikea-contemporary-workspace-by-day-gathering-with-friends-by-night__1364308404935-s4.jpg',
#  'ikea-room-to-draw-play-and-tidy-away__1364311995446-s4.jpg',
#  'ikea-maximise-the-fun-minimise-the-fuss-with-a-modern-changing-table__1364309304966-s4.jpg',
#  'ikea-make-a-bold-statement-with-elegant-all-grey__1364316014730-s4.jpg',
#  'ikea-glossy-open-plan-inspiration__1364308447850-s4.jpg',
#  'ikea-the-perfect-setting-for-family-time__1364308402177-s4.jpg',
#  'ikea-bring-a-bold-graphic-touch-to-your-kitchen-__1364315998559-s4.jpg',
#  'ikea-a-neat-and-space-saving-desk-in-natural-bamboo__1364309611116-s4.jpg',
#  'ikea-a-setting-as-traditional-as-your-sunday-roast__1364308405892-s4.jpg',
#  'ikea-find-your-minimalist-side-with-a-sleek-modern-kitchen__1364316016121-s4.jpg',
#  'ikea-make-your-bedroom-yours-with-a-splash-of-colour__1364308428606-s4.jpg',
#  'ikea-smart-and-sleek-down-to-the-last-centimetre-__1364315996797-s4.jpg',
#  'ikea-soften-stainless-steel-with-pink-accents__1364308463433-s4.jpg',
#  'ikea-storage-that-fits-neatly-into-your-bedroom-and-your-budget__1364309394743-s4.jpg',
#  'ikea-classic-furniture-for-budding-young-artists__1364309507420-s4.jpg',
#  'ikea-standing-workstation-in-smooth-natural-wood__1364311989414-s4.jpg',
#  'ikea-height-adjustable-desk-for-rising-creatives__1364309610439-s4.jpg',
#  'ikea-modern-and-compact-in-dark-brown__1364308511017-s4.jpg',
#  'ikea-find-outdoor-space-you-never-thought-you-had__1364308491911-s4.jpg',
#  'ikea-wake-up-and-grow__1364335362013-s4.jpg',
#  'ikea-wake-up-to-a-warm-wooden-kitchen__1364308434111-s4.jpg',
#  'ikea-lots-of-room-to-dine-in__1364308411084-s4.jpg',
#  'ikea-bamboo-for-something-fresh-and-new__1364315949258-s4.jpg',
#  'ikea-storage-sofa-by-day-comfy-bed-by-night__1364308425779-s4.jpg',
#  'ikea-where-sleep-and-work-come-together-in-harmony__1364309610102-s4.jpg',
#  'ikea-dine-wherever-you-want__1364308412079-s4.jpg',
#  'ikea-country-style-charm-modern-performance__1364309677039-s4.jpg',
#  'ikea-take-your-kitchen-outdoors-this-summer__1364309645281-s4.jpg',
#  'ikea-display-all-your-memorabilia-and-more__1364319313408-s4.jpg',
#  'ikea-mix-grey-white-and-wood-for-a-free-personal-style__1364308465290-s4.jpg',
#  'ikea-striped-scandinavian-style__1364308424350-s4.jpg',
#  'ikea-get-a-classic-look-with-brown-wood-and-glass-doors-__1364308464651-s4.jpg',
#  'ikea-add-a-little-serenity-to-your-bedroom-storage__1364308431819-s4.jpg',
#  'ikea-the-vital-ingredient-in-your-scandi-cool-living-space__1364316016406-s4.jpg',
#  'ikea-a-fresh-way-to-sort-store-and-save-space__1364309607529-s4.jpg',
#  'ikea-storage-for-those-that-like-the-tall-traditional-types__1364308432202-s4.jpg',
#  'ikea-use-the-space-you-have__1364308499054-s4.jpg',
#  'ikea-smart-design-for-tight-spaces__1364309710112-s4.jpg',
#  'ikea-carefully-collected-artfully-displayed__1364309649206-s4.jpg',
#  'ikea-bright-idea-where-every-square-metre-counts__1364309466357-s4.jpg',
#  'ikea-nordic-style-where-design-and-quality-meet__1364315947250-s4.jpg',
#  'ikea-set-your-table-with-scandinavian-style__1364308408633-s4.jpg',
#  'ikea-the-simple-way-to-dine__1364308410298-s4.jpg',
#  'ikea-a-small-hallway-for-big-first-impressions__1364309607844-s4.jpg',
#  'ikea-a-grab-and-go-hallway-for-all-the-family__1364309608195-s4.jpg',
#  'ikea-dotty-decor-for-little-darlings__1364315929694-s4.jpg',
#  'ikea-work-from-home-in-perfect-harmony__1364319311386-s4.jpg',
#  'ikea-breakfast-for-four-dinner-for-six__1364315950047-s4.jpg',
#  'ikea-unwind-in-warm-brown-and-cool-blue__1364308421559-s4.jpg']

# %%
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
from keras.layers import Input, Flatten, Dense
from keras.models import Model
import numpy as np
# Out:
# Using TensorFlow backend.
# /Users/yuanhunglo/anaconda/envs/keras/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/yuanhunglo/anaconda/envs/keras/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/yuanhunglo/anaconda/envs/keras/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/yuanhunglo/anaconda/envs/keras/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/yuanhunglo/anaconda/envs/keras/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/yuanhunglo/anaconda/envs/keras/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
#Get back the convolutional part of a VGG network trained on ImageNet
model_vgg16_conv = VGG16(weights='imagenet', include_top=False)
model_vgg16_conv.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, None, None, 3)     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, None, None, 64)    1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, None, None, 64)    36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, None, None, 64)    0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, None, None, 128)   73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, None, None, 128)   147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, None, None, 128)   0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, None, None, 256)   295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, None, None, 256)   0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, None, None, 512)   1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, None, None, 512)   0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, None, None, 512)   0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
input = Input(shape=(200,200,3), name = 'image_input')

# %%
output_vgg16_conv = model_vgg16_conv(input)

# %%
x = Flatten(name='flatten')(output_vgg16_conv)
x = Dense(4096, activation='relu', name='fc1')(x)
x = Dense(4096, activation='relu', name='fc2')(x)
x = Dense(8, activation='softmax', name='predictions')(x)

# %%
my_model = Model(input=input, output=x)
# Out:
# /Users/yuanhunglo/anaconda/envs/keras/lib/python3.6/site-packages/ipykernel/__main__.py:1: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("im..., outputs=Tensor("pr...)`
#   if __name__ == '__main__':

# %%
my_model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# image_input (InputLayer)     (None, 200, 200, 3)       0
# _________________________________________________________________
# vgg16 (Model)                multiple                  14714688
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              75501568
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 8)                 32776
# =================================================================
# Total params: 107,030,344
# Trainable params: 107,030,344
# Non-trainable params: 0
# _________________________________________________________________

# %%
my_model.input
# Out:
# <tf.Tensor 'image_input_2:0' shape=(?, 200, 200, 3) dtype=float32>

# %%
my_model.output
# Out:
# <tf.Tensor 'predictions/Softmax:0' shape=(?, 8) dtype=float32>

# %%
my_model.get_layer('flatten').output
# Out:
# <tf.Tensor 'flatten/Reshape:0' shape=(?, ?) dtype=float32>

# %%
layers = dict([(layer.name, layer.output) for layer in model_vgg16_conv.layers])

# %%
t = None
if t: 
    print('yes')
else: 
    print('no')
# Out:
# no

# %%
layer_names = [layer.name for layer in model_vgg16_conv.layers]
layer_names
# Out:
# ['input_2',
#  'block1_conv1',
#  'block1_conv2',
#  'block1_pool',
#  'block2_conv1',
#  'block2_conv2',
#  'block2_pool',
#  'block3_conv1',
#  'block3_conv2',
#  'block3_conv3',
#  'block3_pool',
#  'block4_conv1',
#  'block4_conv2',
#  'block4_conv3',
#  'block4_pool',
#  'block5_conv1',
#  'block5_conv2',
#  'block5_conv3',
#  'block5_pool']

# %%
layer_names.index('block5_conv3')
# Out:
# 4

# %%
layer_names
# Out:
# ['block1_conv2',
#  'block2_conv2',
#  'block3_conv3',
#  'block4_conv3',
#  'block5_conv3']

# %%
layer_names = [layer.name for layer in self.model.layers]
# Out:
# layer names: ['block1_conv2', 'block2_conv2', 'block3_conv3', 'block4_conv3', 'block5_conv3']

# %%
# summarize feature map size for each conv layer
from keras.applications.vgg16 import VGG16
from matplotlib import pyplot
from keras.applications.vgg16 import preprocess_input
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.models import Model
from matplotlib import pyplot
from numpy import expand_dims

# # load the model
# model = VGG16()
# # summarize feature map shapes
# for i in range(len(model.layers)):
#     layer = model.layers[i]
#     # check for convolutional layer
#     if 'conv' not in layer.name:
#         continue
#     # summarize output shape
#     print(i, layer.name, layer.output.shape)

# %%
# redefine model to output right after the first hidden layer
model = Model(inputs=model.inputs, outputs=model.layers[1].output)

# %%
# load the image with the required shape
img = load_img('../data/chair/001.530.69.jpg', target_size=(224, 224))

# %%
# convert the image to an array
img = img_to_array(img)
# expand dimensions so that it represents a single 'sample'
img = expand_dims(img, axis=0)

# %%
# prepare the image (e.g. scale pixel values for the vgg)
img = preprocess_input(img)

# %%
# get feature map for first hidden layer
feature_maps = model.predict(img)

# %%
# plot all 64 maps in an 8x8 squares
square = 8
ix = 1
for _ in range(square):
    for _ in range(square):
        # specify subplot and turn of axis
        ax = pyplot.subplot(square, square, ix)
        ax.set_xticks([])
        ax.set_yticks([])
        # plot filter channel in grayscale
        pyplot.imshow(feature_maps[0, :, :, ix-1], cmap='gray')
        ix += 1
# show the figure
pyplot.show()

# %%
# redefine model to output right after the first hidden layer
model = VGG16(weights='imagenet')
# ixs = [2, 5, 9, 13, 17]
# outputs = [model.layers[i+1].output for i in ixs]
# model = Model(inputs=model.inputs, outputs=outputs)
model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 1000)              4097000
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________

# %%
model2 = Model(inputs=model.input, outputs=model.get_layer('block4_pool').output)

# %%
model2.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# =================================================================
# Total params: 7,635,264
# Trainable params: 7,635,264
# Non-trainable params: 0
# _________________________________________________________________

# %%
# visualize feature maps output from each block in the vgg model
from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.models import Model
from matplotlib import pyplot
from numpy import expand_dims
from PIL import Image

# %matplotlib inline
# Out:
# Using TensorFlow backend.
# /Users/yuanhunglo/anaconda/envs/keras/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/yuanhunglo/anaconda/envs/keras/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/yuanhunglo/anaconda/envs/keras/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/yuanhunglo/anaconda/envs/keras/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/yuanhunglo/anaconda/envs/keras/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/yuanhunglo/anaconda/envs/keras/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# load the model
model = VGG16()
# redefine model to output right after the first hidden layer
ixs = [2, 5, 9, 13, 17]
outputs = [model.layers[i].output for i in ixs]
model = Model(inputs=model.inputs, outputs=outputs)
# Out:
# WARNING:tensorflow:From /Users/yuanhunglo/anaconda/envs/keras/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
# load the image with the required shape
# img = load_img('../data/dining_table/302.608.07.jpg', target_size=(224, 224))
img = load_img('../data/chair/202.016.82.jpg', target_size=(224, 224))
# convert the image to an array
img = img_to_array(img)
# expand dimensions so that it represents a single 'sample'
img = expand_dims(img, axis=0)
# prepare the image (e.g. scale pixel values for the vgg)
img = preprocess_input(img)
# get feature map for first hidden layer
feature_maps = model.predict(img)
# plot the output from each block
square = 8
c = 1
for fmap in feature_maps[:1]:
    # plot all 64 maps in an 8x8 squares
    ix = 1
    pyplot.figure(figsize=(8, 6))            
    for _ in range(square):
        for _ in range(square):
            # specify subplot and turn of axis
            ax = pyplot.subplot(square, square, ix)
            ax.set_xticks([])
            ax.set_yticks([])
            # plot filter channel in grayscale
            pyplot.imshow(fmap[0, :, :, ix-1], cmap='gray')
            ix += 1
    pyplot.suptitle(f'c_conv_filter_layer_{c}.png')
    pyplot.savefig(f'c_conv_filter_layer_{c}.png', dpi=300)
    # show the figure
    print(f'{c}')
#     pyplot.show()

    c += 1
# Out:
# 1

# %%
LAYER_NAMES 			= ['block1_conv1', 'block1_conv2']
QUERY_IMAGE_PATH 		= '../data/couch/091.302.38.jpg'
LIB_TYPE 				= 'dining_table'
IMAGE_LIBRARY_PATH 		= '../data/' + LIB_TYPE + '/'
FEATURE_LIBRARY_PATH 	= '../output/indexes/feat_lib_' + LIB_TYPE + '/'
# OUTPUT_IMAGE_PATH 		= '../output/out-' + time.strftime('%Y%m%d-%H%M') + '.png'
OUTPUT_IMAGE_PATH		= f'../output/out-{LAYER_NAMES[0]}-{LAYER_NAMES[1]}'

# %%
OUTPUT_IMAGE_PATH
# Out:
# '../output/out-block1_conv1-block1_conv2'

# %%
import warnings
warnings.filterwarnings(action='once')

from keras.applications import VGG16
from keras.applications.imagenet_utils import preprocess_input
from keras.utils import plot_model
from keras.models import Model
from keras.preprocessing import image
import matplotlib.pyplot as plt
import numpy as np
import os
import random
from sklearn.decomposition import PCA
from scipy.spatial import distance
from PIL import Image

from utils import get_image_paths, load_image, get_concatenated_images, plot_results, pdf_results
from configs import *
from run_style_similarity_search import *
from style_stack import StyleStack
# Out:
# Using TensorFlow backend.
# /Users/yuanhunglo/anaconda/envs/keras/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/yuanhunglo/anaconda/envs/keras/lib/python3.6/importlib/_bootstrap.py:219: ImportWarning: can't resolve package from __spec__ or __package__, falling back on __name__ and __path__
#   return f(*args, **kwds)
# /Users/yuanhunglo/anaconda/envs/keras/lib/python3.6/site-packages/tensorflow/python/keras/backend.py:5201: ResourceWarning: unclosed file <_io.TextIOWrapper name='/Users/yuanhunglo/.keras/keras.json' mode='r' encoding='UTF-8'>
#   _config = json.load(open(_config_path))
# /Users/yuanhunglo/Documents/insight/repos/deep-style-curator/_prototype_style_stack/style_stack.py:93: DeprecationWarning: invalid escape sequence \.
#   info = re.search(f'{input_dir}index-(.+?)-part(.+?)\.index', f)

# %%
# initialize model
image_paths = get_image_paths('../data/bed')
model = VGG16(weights='imagenet', include_top=True)
layer_name, style_feature_model = get_embedding_model(model, 1)
# Out:
# keeping 54 image_paths to analyze

# %%
# generate style embeddings
valid_image_paths, style_embeddings = generate_embeddings(style_feature_model, image_paths)
query_image_idx = int(len(valid_image_paths) * random.random())
# Out:
# analyzing image 0 / 54
# finished extracting 54 embeddings for 54 images with 0 failures

# %%
# generate style features w/ PCA
style_features = pca(style_embeddings, None)

# %%
# find similarity from PCA features based on cosine sim.
closest_image_indices_style = get_closest_indices(query_image_idx, style_features)

# %%
# save results
results_image_paths_style = [valid_image_paths[i] for i in closest_image_indices_style]
save_image(results_image_paths_style)
# Out:
# Result image saved at ../output/image_result.png

# %% [markdown]
# # Modify StyleStack

# %%
# build parameters
image_dir = '../data/chair'
model = VGG16(weights='imagenet', include_top=False)
lib_name = 'raw'
n_results = 5
# Out:
# WARNING:tensorflow:From /Users/yuanhunglo/anaconda/envs/keras/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
# build, save, re-load, query, and plot
stack = StyleStack.build(image_dir, model)
stack.save(lib_name)
del stack
# Out:
# keeping 106 image_paths to analyze
# index time: 889.734 ms

# %%
# 
stack = StyleStack.load(lib_name);
query_image_path = '../data/dining_table/902.224.07.jpg'
results = stack.query(query_image_path, None, n_results, write_output=False);
# Out:
# query time: 581.479 ms
# [72, 4, 23, 18, 65]

# %%
# save results
OUTPUT_DIR = '../output/'
save_image([query_image_path] + results['results_files'], OUTPUT_DIR+'table_chair_4.png')
# Out:
# Result image saved at ../output/image_result.png

# %%
import pickle

# %%
f = open('../data/text_data/products_dict.p', 'rb')
data = pickle.load(f)
data;

# %%
data['002.500.46']
# Out:
# {'name': 'HEMNES',
#  'type': 'Bed frame',
#  'color': 'White stain',
#  'size': 'Standard Single',
#  'img': 'images/objects/002.500.46.jpg',
#  'desc': 'View more product information Made of solid wood, which is a hardwearing and warm natural material.'}

# %%
data['002.392.33']
# Out:
# {'name': 'TUFFING',
#  'type': 'Bunk bed frame',
#  'color': '',
#  'size': '90x200 cm',
#  'img': 'images/objects/002.392.33.jpg',
#  'desc': 'View more product information A good solution where space is limited.'}

# %%
data['690.272.95']
# Out:
# {'name': 'HURDAL',
#  'type': 'Bed frame',
#  'color': 'Light brown,lury',
#  'size': 'Standard Double',
#  'img': 'images/objects/690.272.95.jpg',
#  'desc': 'Mattress and bedlinen are sold separately. View more product information The solid pine shows off the attractive grains and beauty mark knots that give each unique piece its own naturally grown, individual personality.'}

# %% [markdown]
# # Seeing all the furnitures in a room

# %%
import pickle
import os
from PIL import Image
import matplotlib.pyplot as plt

# %%
from itertools import islice
f = open('../data/text_data/item_to_room.p', 'rb')
data = pickle.load(f)
list(islice(data.items(), 5))
# Out:
# [('images/500.210.76.jpg',
#   ['images/room_scenes/ikea-a-colourful-room-for-kids-to-get-creative__1364308442737-s4.jpg',
#    'images/room_scenes/ikea-artist-studio-by-day-cosy-cocoon-by-night__1364319298429-s4.jpg',
#    'images/room_scenes/ikea-artist-studio-by-day-cosy-cocoon-by-night-1364319298711.jpg']),
#  ('images/bed/802.538.09.jpg',
#   ['images/room_scenes/ikea-a-colourful-room-for-kids-to-get-creative__1364308442737-s4.jpg',
#    'images/room_scenes/ikea-big-world-small-scale__1364319297984-s4.jpg',
#    'images/room_scenes/ikea-make-room-for-sleep-and-play__1364308428289-s4.jpg',
#    'images/room_scenes/ikea-room-to-draw-play-and-tidy-away__1364311995446-s4.jpg',
#    'images/room_scenes/ikea-snuggle-down-low-or-sleep-up-high__1364315930176-s4.jpg',
#    'images/room_scenes/ikea-snuggle-down-low-or-sleep-up-high-1364315930147.jpg']),
#  ('images/802.962.48.jpg',
#   ['images/room_scenes/ikea-a-colourful-room-for-kids-to-get-creative__1364308442737-s4.jpg',
#    'images/room_scenes/ikea-quiet-dolls-dinner-party-in-progress__1364315930974-s4.jpg',
#    'images/room_scenes/ikea-quiet-dolls-dinner-party-in-progress-1364315931914.jpg']),
#  ('images/502.962.97.jpg',
#   ['images/room_scenes/ikea-a-colourful-room-for-kids-to-get-creative__1364308442737-s4.jpg',
#    'images/room_scenes/ikea-how-to-sleep-and-surf-in-four-square-metres__1364315935574-s4.jpg',
#    'images/room_scenes/ikea-how-to-sleep-and-surf-in-four-square-metres-1364315936265.jpg']),
#  ('images/203.086.97.jpg',
#   ['images/room_scenes/ikea-a-colourful-room-for-kids-to-get-creative__1364308442737-s4.jpg',
#    'images/room_scenes/ikea-a-colourful-room-for-kids-to-get-creative-1364308442710.jpg'])]

# %%
search_img = 'images/room_scenes/ikea-a-neat-and-space-saving-desk-in-natural-bamboo__1364309611116-s4.jpg'
# search_img = 'images/room_scenes/ikea-a-grab-and-go-hallway-for-all-the-family__1364309608195-s4.jpg'
# search_img = 'images/room_scenes/ikea-a-setting-as-traditional-as-your-sunday-roast__1364308405892-s4.jpg'

for img_fname, room_fname in data.items():
#     if room == ['images/room_scenes/ikea-a-neat-and-space-saving-desk-in-natural-bamboo__1364309611116-s4.jpg']:
#     if room == ['images/room_scenes/ikea-wake-up-ready__1364335382972-s4.jpg']:
    if search_img in room_fname:
        for root, dirs, files in os.walk('../data/'):
            for file in files:
                if file in img_fname[-14:]:
                    fpath = os.path.join(root, file)
#                     print(fpath)
                    img = Image.open(fpath)
                    plt.figure(figsize=(6,4))
                    plt.imshow(img)
                    plt.title(fpath)

# %%
img[-14:]
# Out:
# '202.584.85.jpg'

# %% [markdown]
# # create furniture labels

# %% [markdown]
# # check style transfer pipeline

# %%
from keras import backend
import numpy as np

# %%
IMAGE_HEIGHT = IMAGE_WIDTH = 300
input_image = Image.open('../data/bed/001.024.52.jpg')
input_image = input_image.resize((IMAGE_WIDTH, IMAGE_HEIGHT))
input_image_array = np.asarray(input_image, dtype="float32")
input_image_array = np.expand_dims(input_image_array, axis=0)
input_image_array = input_image_array[:, :, :, ::-1]

style_image = Image.open('../data/bed/001.626.34.jpg')
style_image = style_image.resize((IMAGE_WIDTH, IMAGE_HEIGHT))
style_image_array = np.asarray(style_image, dtype="float32")
style_image_array = np.expand_dims(style_image_array, axis=0)
# style_image_array[:, :, :, 0] -= IMAGENET_MEAN_RGB_VALUES[2]
# style_image_array[:, :, :, 1] -= IMAGENET_MEAN_RGB_VALUES[1]
# style_image_array[:, :, :, 2] -= IMAGENET_MEAN_RGB_VALUES[0]
style_image_array = style_image_array[:, :, :, ::-1]

# %%
style_image_array.shape
# Out:
# (1, 300, 300, 3)

# %%
CONTENT_LAYER = "block2_conv2"
STYLE_LAYERS = ["block1_conv2", "block2_conv2", "block3_conv3", "block4_conv3", "block5_conv3"]
CONTENT_WEIGHT = 0.5

input_image = backend.variable(input_image_array)
style_image = backend.variable(style_image_array)
combination_image = backend.placeholder((1, IMAGE_HEIGHT, IMAGE_WIDTH, 3))

# Load pre-trained VGG16
input_tensor = backend.concatenate([input_image, style_image, combination_image], axis=0)
model = VGG16(input_tensor=input_tensor, include_top=False)
layers = dict([(layer.name, layer.output) for layer in model.layers])
loss = backend.variable(0.)

# Define content layer and loss
layer_features = layers[CONTENT_LAYER]
content_image_features = layer_features[0, :, :, :]
combination_features = layer_features[2, :, :, :]
# loss = loss + CONTENT_WEIGHT * content_loss(content_image_features, combination_features)

# %%
# content_image_features
layers
# Out:
# {'input_10': <tf.Tensor 'concat_7:0' shape=(3, 300, 300, 3) dtype=float32>,
#  'block1_conv1': <tf.Tensor 'block1_conv1_9/Relu:0' shape=(3, 300, 300, 64) dtype=float32>,
#  'block1_conv2': <tf.Tensor 'block1_conv2_9/Relu:0' shape=(3, 300, 300, 64) dtype=float32>,
#  'block1_pool': <tf.Tensor 'block1_pool_9/MaxPool:0' shape=(3, 150, 150, 64) dtype=float32>,
#  'block2_conv1': <tf.Tensor 'block2_conv1_9/Relu:0' shape=(3, 150, 150, 128) dtype=float32>,
#  'block2_conv2': <tf.Tensor 'block2_conv2_9/Relu:0' shape=(3, 150, 150, 128) dtype=float32>,
#  'block2_pool': <tf.Tensor 'block2_pool_9/MaxPool:0' shape=(3, 75, 75, 128) dtype=float32>,
#  'block3_conv1': <tf.Tensor 'block3_conv1_9/Relu:0' shape=(3, 75, 75, 256) dtype=float32>,
#  'block3_conv2': <tf.Tensor 'block3_conv2_9/Relu:0' shape=(3, 75, 75, 256) dtype=float32>,
#  'block3_conv3': <tf.Tensor 'block3_conv3_9/Relu:0' shape=(3, 75, 75, 256) dtype=float32>,
#  'block3_pool': <tf.Tensor 'block3_pool_9/MaxPool:0' shape=(3, 37, 37, 256) dtype=float32>,
#  'block4_conv1': <tf.Tensor 'block4_conv1_9/Relu:0' shape=(3, 37, 37, 512) dtype=float32>,
#  'block4_conv2': <tf.Tensor 'block4_conv2_9/Relu:0' shape=(3, 37, 37, 512) dtype=float32>,
#  'block4_conv3': <tf.Tensor 'block4_conv3_9/Relu:0' shape=(3, 37, 37, 512) dtype=float32>,
#  'block4_pool': <tf.Tensor 'block4_pool_9/MaxPool:0' shape=(3, 18, 18, 512) dtype=float32>,
#  'block5_conv1': <tf.Tensor 'block5_conv1_9/Relu:0' shape=(3, 18, 18, 512) dtype=float32>,
#  'block5_conv2': <tf.Tensor 'block5_conv2_9/Relu:0' shape=(3, 18, 18, 512) dtype=float32>,
#  'block5_conv3': <tf.Tensor 'block5_conv3_9/Relu:0' shape=(3, 18, 18, 512) dtype=float32>,
#  'block5_pool': <tf.Tensor 'block5_pool_9/MaxPool:0' shape=(3, 9, 9, 512) dtype=float32>}

# %%
for fmap in feature_maps:
    # plot all 64 maps in an 8x8 squares
    ix = 1
    pyplot.figure(figsize=(8, 6))            
    for _ in range(square):
        for _ in range(square):
            # specify subplot and turn of axis
            ax = pyplot.subplot(square, square, ix)
            ax.set_xticks([])
            ax.set_yticks([])
            # plot filter channel in grayscale
            pyplot.imshow(fmap[0, :, :, ix-1], cmap='gray')
            ix += 1
